# %%
import os

# %%
import glob

# %%
from IPython.display import Image, display

# %%
# !nvidia-smi
# Out:
# Sat Apr 19 08:50:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
HOME = os.getcwd()

# %%
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics==8.0.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.8/219.8 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 36.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# ...

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.0 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.0/112.6 GB disk)

# %%
# !mkdir {HOME}/datasets

# %%
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Pm7Olrh5oBEGtQBJTTJ8")
project = rf.workspace("usmanchaudhry622-gmail-com").project("traffic-and-road-signs")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !pip install --upgrade ultralytics

# %%
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 18.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.11.0.86
#     Uninstalling opencv-python-4.11.0.86:
#       Successfully uninstalled opencv-python-4.11.0.86
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.15
#     Uninstalling aiohttp-3.11.15:
#       Successfully uninstalled aiohttp-3.11.15
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolov8s.pt data="/content/datasets/Traffic-and-Road-Signs-1/data.yaml" epochs=30 imgsz=640
# Out:
# /content
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

# Load model
try:
    model = YOLO("/content/yolov8s.pt")
    print("Model loaded successfully!")
except Exception as e:
    print(f"Error loading model: {e}")
# Out:
# Error loading model: Weights only load failed. This file can still be loaded, to do so you have two options, do those steps only if you trust the source of the checkpoint.
# 	(1) In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# 	(2) Alternatively, to load with `weights_only=True` please check the recommended steps in the following error message.
# 	WeightsUnpickler error: Unsupported global: GLOBAL ultralytics.nn.tasks.DetectionModel was not an allowed global by default. Please use `torch.serialization.add_safe_globals([DetectionModel])` or the `torch.serialization.safe_globals([DetectionModel])` context manager to allowlist this global if you trust this class/function.
#
# ...

# %%
# !ls {HOME}/runs/detect/train
# Out:
# args.yaml  weights

# %%
#printing the confusion matrix
from IPython.display import Image
Image(filename='/content/runs/detect/train3/confusion_matrix.png', width=600)

# %%
#check predictions on validations
Image(filename="/content/runs/detect/train3/val_batch2_labels.jpg", height=600)

# %%
#printing the training and validation loss
from IPython.display import Image
Image(filename="/content/runs/detect/train3/results.png", width=600)

# %%
#validate custom model
# !yolo task=detect mode=val model='/content/runs/detect/train3/weights/best.pt' data="/content/datasets/Traffic-and-Road-Signs-1/data.yaml"
# Out:
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,136,807 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 762.3±236.8 MB/s, size: 15.4 KB)
# val: Scanning /content/datasets/Traffic-and-Road-Signs-1/valid/labels.cache... 1884 images, 0 backgrounds, 0 corrupt: 100% 1884/1884 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 118/118 [00:24<00:00,  4.83it/s]
#                    all       1884       1886      0.958      0.944      0.937      0.811
# -Road narrows on right         54         54      0.997          1      0.995      0.912
#     50 mph speed limit         62         62      0.544          1      0.672      0.563
#      Attention Please-        117        117      0.999          1      0.995       0.88
#     Beware of children        106        106          1      0.994      0.995      0.903
# ...

# %%
#inference with custom model
# !gdown "https://drive.google.com/file/d/1EH4hJMpdvqGcaO3Kct69uTNb92C2qAfx/view?usp=drive_link"
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=1EH4hJMpdvqGcaO3Kct69uTNb92C2qAfx
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/1EH4hJMpdvqGcaO3Kct69uTNb92C2qAfx/view?usp=drive_link
# To: /content/view?usp=drive_link
# 35.1kB [00:00, 2.76MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

print(os.path.exists("/content/yolov8s.pt"))
# Out:
# True

# %%
#run the predict.py script
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8s.pt data="/content/runs/detect/train3/weights/best.pt" source='/content/drive/MyDrive/traffic_sign_recognition/test1.mp4'
# Out:
# /content
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8s summary (fused): 72 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
#
# video 1/1 (frame 1/529) /content/drive/MyDrive/traffic_sign_recognition/test1.mp4: 384x640 13 persons, 3 cars, 4 traffic lights, 1 suitcase, 42.2ms
# video 1/1 (frame 2/529) /content/drive/MyDrive/traffic_sign_recognition/test1.mp4: 384x640 14 persons, 2 cars, 4 traffic lights, 1 suitcase, 11.0ms
# video 1/1 (frame 3/529) /content/drive/MyDrive/traffic_sign_recognition/test1.mp4: 384x640 12 persons, 2 cars, 1 bus, 4 traffic lights, 1 suitcase, 11.0ms
# video 1/1 (frame 4/529) /content/drive/MyDrive/traffic_sign_recognition/test1.mp4: 384x640 11 persons, 2 cars, 1 bus, 4 traffic lights, 1 suitcase, 11.0ms
# video 1/1 (frame 5/529) /content/drive/MyDrive/traffic_sign_recognition/test1.mp4: 384x640 10 persons, 2 cars, 1 bus, 4 traffic lights, 1 suitcase, 11.1ms
# ...

# %%
# !ls runs/detect/predict
# Out:
# test1.avi

# %%
# !ffmpeg -y -i runs/detect/predict/test1.avi runs/detect/predict/test1.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode

video_path = 'runs/detect/predict/test1.mp4'

mp4 = open(video_path, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f'<video width=720 controls><source src="{data_url}" type="video/mp4"></video>')

# %% [markdown]
# VIDEO TEST 2

# %%
#run the predict.py script
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8s.pt data="/content/runs/detect/train3/weights/best.pt" source='/content/drive/MyDrive/traffic_sign_recognition/test2.mp4'
# Out:
# /content
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8s summary (fused): 72 layers, 11,156,544 parameters, 0 gradients, 28.6 GFLOPs
#
# video 1/1 (frame 1/240) /content/drive/MyDrive/traffic_sign_recognition/test2.mp4: 640x384 2 persons, 4 cars, 5 traffic lights, 40.7ms
# video 1/1 (frame 2/240) /content/drive/MyDrive/traffic_sign_recognition/test2.mp4: 640x384 2 persons, 4 cars, 5 traffic lights, 11.7ms
# video 1/1 (frame 3/240) /content/drive/MyDrive/traffic_sign_recognition/test2.mp4: 640x384 3 persons, 4 cars, 4 traffic lights, 11.7ms
# video 1/1 (frame 4/240) /content/drive/MyDrive/traffic_sign_recognition/test2.mp4: 640x384 2 persons, 4 cars, 4 traffic lights, 11.0ms
# video 1/1 (frame 5/240) /content/drive/MyDrive/traffic_sign_recognition/test2.mp4: 640x384 2 persons, 3 cars, 3 traffic lights, 10.9ms
# ...

# %%
# !ls runs/detect/predict2
# Out:
# test2.avi

# %%
# !ffmpeg -y -i runs/detect/predict2/test2.avi runs/detect/predict2/test2.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode

video_path = 'runs/detect/predict2/test2.mp4'

mp4 = open(video_path, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f'<video width=720 controls><source src="{data_url}" type="video/mp4"></video>')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0a1efc99-39ea-4dc0-a469-e383e9f5ed97" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a1efc99-39ea-4dc0-a469-e383e9f5ed97">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# TEST 3

# %%
#run the predict.py script
# %cd {HOME}
# !yolo task=detect mode=predict model="/content/runs/detect/train3/weights/best.pt" source='/content/drive/MyDrive/traffic_sign_recognition/test3.mp4'
# Out:
# /content
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,136,807 parameters, 0 gradients, 28.5 GFLOPs
#
# video 1/1 (frame 1/969) /content/drive/MyDrive/traffic_sign_recognition/test3.mp4: 384x640 1 Traffic_signal, 42.6ms
# video 1/1 (frame 2/969) /content/drive/MyDrive/traffic_sign_recognition/test3.mp4: 384x640 1 Traffic_signal, 10.8ms
# video 1/1 (frame 3/969) /content/drive/MyDrive/traffic_sign_recognition/test3.mp4: 384x640 1 Traffic_signal, 10.8ms
# video 1/1 (frame 4/969) /content/drive/MyDrive/traffic_sign_recognition/test3.mp4: 384x640 1 Traffic_signal, 10.8ms
# video 1/1 (frame 5/969) /content/drive/MyDrive/traffic_sign_recognition/test3.mp4: 384x640 1 Traffic_signal, 10.8ms
# video 1/1 (frame 6/969) /content/drive/MyDrive/traffic_sign_recognition/test3.mp4: 384x640 1 Traffic_signal, 10.8ms
# ...

# %%
# !ls runs/detect/predict6
# Out:
# test3.avi

# %%
# !ffmpeg -y -i runs/detect/predict6/test3.avi runs/detect/predict6/test3.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode

video_path = 'runs/detect/predict6/test3.mp4'

mp4 = open(video_path, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f'<video width=720 controls><source src="{data_url}" type="video/mp4"></video>')

# %% [markdown]
# TEST 4

# %%
#run the predict.py script
# !yolo task=detect mode=predict model="/content/runs/detect/train3/weights/best.pt" source='/content/drive/MyDrive/traffic_sign_recognition/test4.mp4'
# Out:
# /content
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,136,807 parameters, 0 gradients, 28.5 GFLOPs
#
# video 1/1 (frame 1/1608) /content/drive/MyDrive/traffic_sign_recognition/test4.mp4: 384x640 2 Traffic_signals, 39.1ms
# video 1/1 (frame 2/1608) /content/drive/MyDrive/traffic_sign_recognition/test4.mp4: 384x640 2 Traffic_signals, 10.8ms
# video 1/1 (frame 3/1608) /content/drive/MyDrive/traffic_sign_recognition/test4.mp4: 384x640 2 Traffic_signals, 10.8ms
# video 1/1 (frame 4/1608) /content/drive/MyDrive/traffic_sign_recognition/test4.mp4: 384x640 2 Traffic_signals, 10.8ms
# video 1/1 (frame 5/1608) /content/drive/MyDrive/traffic_sign_recognition/test4.mp4: 384x640 2 Traffic_signals, 10.8ms
# video 1/1 (frame 6/1608) /content/drive/MyDrive/traffic_sign_recognition/test4.mp4: 384x640 2 Traffic_signals, 12.8ms
# ...

# %%
# !ls runs/detect/predict5
# Out:
# test4.avi

# %%
# !ffmpeg -y -i runs/detect/predict5/test4.avi runs/detect/predict5/test4.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode

video_path = 'runs/detect/predict5/test4.mp4'

mp4 = open(video_path, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f'<video width=720 controls><source src="{data_url}" type="video/mp4"></video>')
